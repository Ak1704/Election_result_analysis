# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read csv files

# %%
bjp_df = pd.read_csv("bjp.csv")
congress_df = pd.read_csv("congress.csv")
dmk_df = pd.read_csv("dmk.csv")
total_party_data = pd.read_csv("total_ds.csv")
TN_result = pd.read_csv("TN_result.csv")
UP_result = pd.read_csv("UP_results.csv")
KL_result = pd.read_csv("KL_results.csv")

# %%
bjp_df.head()
# Out:
#    Unnamed: 0  S.No Parliament Constituency  \
# 0           0     1           Anakapalle(5)
# 1           1     2          Rajahmundry(8)
# 2           2     3           Narsapuram(9)
# 3           3     4       Arunachal West(1)
# 4           4     5       Arunachal East(2)
#
#                              Winning Candidate Total Votes  Margin
# 0                                   C.M.RAMESH      762069  296530
# 1                     DAGGUBATI PURANDHESHWARI      726515  239139
# 2  BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)      707343  276802
# 3                                 KIREN RIJIJU      205417  100738
# 4                                    TAPIR GAO      145581   30421

# %%
congress_df.head()
# Out:
#    Unnamed: 0  S.No Parliament Constituency Winning Candidate  Total Votes  \
# 0           0     1              Dhubri (2)   RAKIBUL HUSSAIN      1471885
# 1           1     2               Nagaon(9)  PRADYUT BORDOLOI       788850
# 2           2     3              Jorhat(14)      GAURAV GOGOI       751771
# 3           3     4          Kishanganj(10)    MOHAMMAD JAWED       402850
# 4           4     5             Katihar(11)       TARIQ ANWAR       567092
#
#     Margin
# 0  1012476
# 1   212231
# 2   144393
# 3    59692
# 4    49863

# %%
total_party_data.head()
# Out:
#    Unnamed: 0  S.No Parliament Constituency  \
# 0           0     1           Anakapalle(5)
# 1           1     2          Rajahmundry(8)
# 2           2     3           Narsapuram(9)
# 3           3     4       Arunachal West(1)
# 4           4     5       Arunachal East(2)
#
#                              Winning Candidate Total Votes  Margin
# 0                                   C.M.RAMESH      762069  296530
# 1                     DAGGUBATI PURANDHESHWARI      726515  239139
# 2  BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)      707343  276802
# 3                                 KIREN RIJIJU      205417  100738
# 4                                    TAPIR GAO      145581   30421

# %%
TN_result.head()
# Out:
#    Unnamed: 0     Constituency  Const. No.  \
# 0           0        ARAKKONAM           7
# 1           1            ARANI          12
# 2           2  CHENNAI CENTRAL           4
# 3           3    CHENNAI NORTH           2
# 4           4    CHENNAI SOUTH           3
#
#                              Leading Candidate              Leading Party  \
# 0                            S JAGATHRATCHAKAN  Dravida Munnetra Kazhagam
# 1                           THARANIVENTHAN M S  Dravida Munnetra Kazhagam
# 2                              DAYANIDHI MARAN  Dravida Munnetra Kazhagam
# 3                      DR.KALANIDHI VEERASWAMY  Dravida Munnetra Kazhagam
# 4  T.SUMATHY (ALIAS) THAMIZHACHI THANGAPANDIAN  Dravida Munnetra Kazhagam
#
#    Won          Trailing Candidate                            Trailing Party  \
# 0   22                   L VIJAYAN  All India Anna Dravida Munnetra Kazhagam
# 1   22             GAJENDRAN, G.V.  All India Anna Dravida Munnetra Kazhagam
# 2   22                       VINOJ                    Bharatiya Janata Party
# 3   22                  R. MANOHAR  All India Anna Dravida Munnetra Kazhagam
# 4   22  DR.TAMILISAI SOUNDARARAJAN                    Bharatiya Janata Party
#
#    Margin
# 0  306559
# 1  208766
# 2  244689
# 3  339222
# 4  225945

# %%
UP_result.head()
# Out:
#    Unnamed: 0    Constituency  Const. No.                 Leading Candidate  \
# 0           0            Agra          18             PROF S P SINGH BAGHEL
# 1           1        Akbarpur          44  DEVENDRA SINGH ALIAS BHOLE SINGH
# 2           2         Aligarh          15               SATISH KUMAR GAUTAM
# 3           3       Allahabad          52                UJJWAL RAMAN SINGH
# 4           4  Ambedkar Nagar          55                       LALJI VERMA
#
#               Leading Party  Won   Trailing Candidate          Trailing Party  \
# 0    Bharatiya Janata Party   33  SURESH CHAND KARDAM         Samajwadi Party
# 1    Bharatiya Janata Party   33          RAJARAM PAL         Samajwadi Party
# 2    Bharatiya Janata Party   33       BIJENDRA SINGH         Samajwadi Party
# 3  Indian National Congress    6      NEERAJ TRIPATHI  Bharatiya Janata Party
# 4           Samajwadi Party   37        RITESH PANDEY  Bharatiya Janata Party
#
#    Margin
# 0  271294
# 1   44345
# 2   15647
# 3   58795
# 4  137247

# %%
KL_result.head()
# Out:
#    Unnamed: 0 Constituency  Const. No.  Leading Candidate  \
# 0           0    Alappuzha          15     K. C VENUGOPAL
# 1           1     Alathur            9    K.RADHAKRISHNAN
# 2           2     Attingal          19  ADV ADOOR PRAKASH
# 3           3    Chalakudy          11      BENNY BEHANAN
# 4           4    Ernakulam          12          HIBI EDEN
#
#                          Leading Party  Won    Trailing Candidate  \
# 0             Indian National Congress   14            A. M ARIFF
# 1  Communist Party of India  (Marxist)    1         RAMYA HARIDAS
# 2             Indian National Congress   14                 V JOY
# 3             Indian National Congress   14  PROF C RAVEENDRANATH
# 4             Indian National Congress   14   K. J. SHINE TEACHER
#
#                         Trailing Party  Margin
# 0  Communist Party of India  (Marxist)   63513
# 1             Indian National Congress   20111
# 2  Communist Party of India  (Marxist)     684
# 3  Communist Party of India  (Marxist)   63754
# 4  Communist Party of India  (Marxist)  250385

# %% [markdown]
# ##Parties with Highest Votes in each state

# %%
party_votes_tn = TN_result.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
party_votes_tn
# Out:
# Leading Party
# Dravida Munnetra Kazhagam                 11098034
# Indian National Congress                   4932970
# Communist Party of India  (Marxist)        2612920
# Communist Party of India                    961756
# Viduthalai Chiruthaigal Katchi              484919
# Marumalarchi Dravida Munnetra Kazhagam      313094
# Indian Union Muslim League                  166782
# Name: Margin, dtype: int64

# %%
tn_party_l = ['DMK','Congress', 'CPI-M','CPI','VCK','MDMK','IUML']
plt.bar(tn_party_l,party_votes_tn)
plt.show()

# %% [markdown]
# #The above chart shows dmk party won with a margin more than double compared to the other parties. which

# %%
party_votes_up = UP_result.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
party_votes_up
# Out:
# Leading Party
# Bharatiya Janata Party            3501557
# Samajwadi Party                   2869566
# Indian National Congress           985908
# Rashtriya Lok Dal                  196967
# Aazad Samaj Party (Kanshi Ram)     151473
# Apna Dal (Soneylal)                 37810
# Name: Margin, dtype: int64

# %%
up_party_l = ['BJP','SJ', 'Congress','RLD','ASP','AD']
plt.bar(up_party_l,party_votes_up)
plt.show()

# %% [markdown]
# The above chart shows that the Party BJP got more votes than the Samajwadi party

# %%
party_votes_kl = KL_result.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
party_votes_kl
# Out:
# Leading Party
# Indian National Congress               1515145
# Indian Union Muslim League              535878
# Revolutionary Socialist Party           150302
# Kerala Congress                          87266
# Bharatiya Janata Party                   74686
# Communist Party of India  (Marxist)      20111
# Name: Margin, dtype: int64

# %%
kl_party_l = ['Congress','IUML', 'RSP','K_congress','BJP','CPI_M']
plt.bar(kl_party_l,party_votes_kl)
plt.show()

# %%
won_result = pd.read_csv("Won_result.csv")
fig, ax = plt.subplots() 
wl=won_result.values.tolist()
ax.stem(won_result.columns,wl[0])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Analysis of Famous leaders in india

# %%
rahul_g_entries = congress_df[congress_df["Winning Candidate"]=="RAHUL GANDHI"]
modi_entries = bjp_df[bjp_df["Winning Candidate"] == "NARENDRA MODI"]
amit_shah_entries = bjp_df[bjp_df["Winning Candidate"] == "AMIT SHAH"]
rahul_votes = list(rahul_g_entries["Total Votes"])
modi_votes = int(modi_entries["Total Votes"].values[0])
amit_shah_votes = int(amit_shah_entries["Total Votes"].values[0])

# %%
consistuency_l = list(rahul_g_entries["Parliament Constituency"])+[modi_entries["Parliament Constituency"].values[0]]+[amit_shah_entries["Parliament Constituency"].values[0]]
consistuency_l
# Out:
# ['Wayanad(4)', 'Rae Bareli(36)', 'Varanasi(77)', 'Gandhinagar(6)']

# %%
votes_list = rahul_votes+[modi_votes]+[amit_shah_votes]
c_list = ['rahul-1','rahul-2','modi','amit shah']
plt.bar(c_list,votes_list)
plt.bar(consistuency_l,votes_list,color="orange")
plt.xlabel("Leaders/Consituency")
plt.ylabel("Votes in each consistuency")
plt.xticks(rotation=90)
plt.show()

# %%
total_df = total_party_data.sort_values(by="Total Votes",ascending = 0)
high_votes_list = list(total_df["Total Votes"].values[:6])
cand_list = list(total_df["Winning Candidate"].values[:6])
consistuency_list = list(total_df["Parliament Constituency"].values[:6])
plt.bar(cand_list,high_votes_list)
plt.bar(consistuency_list,high_votes_list,color="orange")
plt.xlabel("Leaders/Consituency")
plt.ylabel("Votes in each consistuency")
plt.xticks(rotation=90)
plt.show()

# %%
total_df.replace('-', 0, inplace=True)
total_df[["Margin","Total Votes"]] = total_df[["Margin","Total Votes"]].astype(int)
total_df["margin-votes ratio"] = (total_df["Margin"]/total_df["Total Votes"])*100
total_df["margin-votes ratio"] = total_df["margin-votes ratio"].fillna(100)
ratio_list = list(total_df["margin-votes ratio"].values)
plt.bar(consistuency_list,ratio_list[:6],color="orange")
plt.xlabel("Consituency with maximum margin-votes ratio")
plt.ylabel("Margin to Vote ratio")
plt.xticks(rotation=90)
plt.show()

# %%
tail_cons_list = list(total_df["Parliament Constituency"].tail().values)
tail_ratio_list = list(total_df["margin-votes ratio"].tail().values)
plt.bar(tail_cons_list,tail_ratio_list)
plt.xlabel("Consituency with minimum margin-votes ratio")
plt.ylabel("Margin-Votes Ratio")
plt.xticks(rotation=90)
plt.show()

# %%
poll_list=pd.read_csv("voter_list.csv")
poll_list.head()
# Out:
#    Unnamed: 0  Sl.No                      State                    PC Name  \
# 0           0      1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1           1      2          Arunachal Pradesh             Arunachal East
# 2           2      3          Arunachal Pradesh             Arunachal West
# 3           3      4                      Assam                  Dibrugarh
# 4           4      5                      Assam                     Jorhat
#
#    Count of Elector  Poll(%)  Count of Votes
# 0            315148    64.10          202018
# 1            375310    83.31          312658
# 2            517384    73.60          380783
# 3           1659588    76.75         1273744
# 4           1727121    79.89         1379749

# %%
poll_list = poll_list.sort_values(by="Poll(%)",ascending = 0)
pc_list = list(poll_list["PC Name"].head().values)
poll_per = list(poll_list["Poll(%)"].head().values)
poll_count = list(poll_list["Count of Elector"].head().values)
plt.bar(pc_list,poll_per,color="purple")
plt.xlabel("Consituency with highest Poll(%)")
plt.ylabel("Poll(%)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(pc_list,poll_count)
plt.xlabel("Consituency with highest Poll(%)")
plt.ylabel("Number of elegible voters")
plt.show()

# %%
pc_list_tail = list(poll_list["PC Name"].tail().values)
poll_per_tail = list(poll_list["Poll(%)"].tail().values)
poll_count_tail = list(poll_list["Count of Elector"].tail().values)
plt.bar(pc_list_tail,poll_per_tail,color="orange")
plt.xlabel("Consituency with Lowest Poll(%)")
plt.ylabel("Poll(%)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(pc_list_tail,poll_count_tail)
plt.xlabel("Consituency with Lowest Poll(%)")
plt.ylabel("Number of Eligible Voters")
plt.show()

# %%
import re
def find_cno(row):
    res = re.findall(r'\(.*?\)', row)
    return res[0]
total_df["Consistuency_no"] = total_df["Parliament Constituency"] .apply(find_cno)
def remove_brac(row):
    string=re.sub("\(.*?\)","",row)
    return string.upper()
total_df["Parliament Constituency"] = total_df["Parliament Constituency"] .apply(remove_brac)
poll_list["PC Name"] = poll_list["PC Name"].apply(remove_brac)
#poll_list.rename(columns = {'PC Name':'Parliament Constituency'}, inplace = True)

# %%
party_vote_list = pd.merge(total_df, poll_list, left_on = 'Parliament Constituency', right_on = 'PC Name', how = 'left')
party_vote_list = party_vote_list.drop(["Sl.No","S.No","Unnamed: 0_x","Unnamed: 0_y","PC Name"],axis=1)
party_vote_list.head()
# Out:
#   Parliament Constituency  Winning Candidate  Total Votes  Margin  \
# 0              MALKAJGIRI    EATALA RAJENDER       991042  391475
# 1         BANGALORE NORTH  SHOBHA KARANDLAJE       986049  259476
# 2                  BHOPAL        ALOK SHARMA       981109  501499
# 3                    DURG       VIJAY BAGHEL       956497  438226
# 4                MANDSOUR      SUDHEER GUPTA       945761  500655
#
#    margin-votes ratio Consistuency_no           State  Count of Elector  \
# 0           39.501353             (7)       Telangana         3779596.0
# 1           26.314717            (24)       Karnataka         3214496.0
# 2           51.115523            (19)  Madhya Pradesh         2339411.0
# 3           45.815721             (7)    Chhattisgarh         2090414.0
# 4           52.936736            (23)  Madhya Pradesh         1898060.0
#
#    Poll(%)  Count of Votes
# 0    50.78       1919131.0
# 1    54.45       1750372.0
# 2    64.06       1498626.0
# 3    73.68       1540193.0
# 4    75.27       1428623.0

# %%
duplicate = party_vote_list["Consistuency_no"][party_vote_list["Consistuency_no"].duplicated()]
duplicate
# Out:
# 3       (7)
# 7       (4)
# 10     (19)
# 11     (21)
# 12      (7)
#        ...
# 541    (21)
# 542    (25)
# 543     (1)
# 544     (6)
# 545    (24)
# Name: Consistuency_no, Length: 464, dtype: object

# %%
nan_count = party_vote_list.isna().sum()
print('Nan count',nan_count)
df1 = party_vote_list[party_vote_list.isna().any(axis=1)]
df1
# Out:
# Nan count Parliament Constituency      0
# Winning Candidate            0
# Total Votes                  0
# Margin                       0
# margin-votes ratio           0
# Consistuency_no              0
# State                      123
# Count of Elector           123
# Poll(%)                    123
# Count of Votes             123
# dtype: int64
#     Parliament Constituency                             Winning Candidate  \
# 10                 JOYNAGAR                                PRATIMA MONDAL
# 16         NORTH-WEST DELHI                           YOGENDER CHANDOLIYA
# 27               WEST DELHI                            KAMALJEET SEHRAWAT
# 28                   GHATAL                         ADHIKARI DEEPAK (DEV)
# 30         NORTH-EAST DELHI                                  MANOJ TIWARI
# ..                      ...                                           ...
# 525                FIROZPUR                            SHER SINGH GHUBAYA
# 528                AMRITSAR                           GURJEET SINGH AUJLA
# 530              CHANDIGARH                                 MANISH TEWARI
# 541         DIAMOND HARBOUR                             ABHISHEK BANERJEE
# 545                   SURAT  MUKESHKUMAR CHANDRAKAANT DALAL (Uncontested)
#
#      Total Votes  Margin  margin-votes ratio Consistuency_no State  \
# 10        894312  470219           52.578854            (19)   NaN
# 16        866483  290849           33.566614             (5)   NaN
# 27        842658  199013           23.617292             (6)   NaN
# 28        837990  182868           21.822217            (32)   NaN
# 30        824451  138778           16.832777             (2)   NaN
# ..           ...     ...                 ...             ...   ...
# 525       266626    3242            1.215935            (10)   NaN
# 528       255181   40301           15.793104             (2)   NaN
# 530       216657    2504            1.155744             (1)   NaN
# 541      1048230  710930           67.821947            (21)   NaN
# 545            0       0          100.000000            (24)   NaN
#
#      Count of Elector  Poll(%)  Count of Votes
# 10                NaN      NaN             NaN
# 16                NaN      NaN             NaN
# 27                NaN      NaN             NaN
# 28                NaN      NaN             NaN
# 30                NaN      NaN             NaN
# ..                ...      ...             ...
# 525               NaN      NaN             NaN
# 528               NaN      NaN             NaN
# 530               NaN      NaN             NaN
# 541               NaN      NaN             NaN
# 545               NaN      NaN             NaN
#
# [123 rows x 10 columns]

# %%
party_vote_list = party_vote_list.dropna(how='any',axis=0) 
nan_count = party_vote_list.isna().sum()
print('Nan count',nan_count)
party_vote_list
# Out:
# Nan count Parliament Constituency    0
# Winning Candidate          0
# Total Votes                0
# Margin                     0
# margin-votes ratio         0
# Consistuency_no            0
# State                      0
# Count of Elector           0
# Poll(%)                    0
# Count of Votes             0
# dtype: int64
#        Parliament Constituency  Winning Candidate  Total Votes  Margin  \
# 0                   MALKAJGIRI    EATALA RAJENDER       991042  391475
# 1              BANGALORE NORTH  SHOBHA KARANDLAJE       986049  259476
# 2                       BHOPAL        ALOK SHARMA       981109  501499
# 3                         DURG       VIJAY BAGHEL       956497  438226
# 4                     MANDSOUR      SUDHEER GUPTA       945761  500655
# ..                         ...                ...          ...     ...
# 539            BANGALORE RURAL   DR C N MANJUNATH      1079002  269647
# 540                     RAIPUR  BRIJMOHAN AGRAWAL      1050351  575285
# 542                    NAVSARI          C R PATIL      1031065  773551
# 543  ANDAMAN & NICOBAR ISLANDS    BISHNU PADA RAY       102436   24396
# 544                GANDHINAGAR          AMIT SHAH      1010972  744716
#
#      margin-votes ratio Consistuency_no                      State  \
# 0             39.501353             (7)                  Telangana
# 1             26.314717            (24)                  Karnataka
# 2             51.115523            (19)             Madhya Pradesh
# 3             45.815721             (7)               Chhattisgarh
# 4             52.936736            (23)             Madhya Pradesh
# ..                  ...             ...                        ...
# 539           24.990408            (23)                  Karnataka
# 540           54.770739             (8)               Chhattisgarh
# 542           75.024465            (25)                    Gujarat
# 543           23.815846             (1)  Andaman & Nicobar Islands
# 544           73.663366             (6)                    Gujarat
#
#      Count of Elector  Poll(%)  Count of Votes
# 0           3779596.0    50.78       1919131.0
# 1           3214496.0    54.45       1750372.0
# 2           2339411.0    64.06       1498626.0
# 3           2090414.0    73.68       1540193.0
# 4           1898060.0    75.27       1428623.0
# ..                ...      ...             ...
# 539         2802580.0    68.30       1914030.0
# 540         2375379.0    66.82       1587116.0
# 542         2223550.0    59.66       1326542.0
# 543          315148.0    64.10        202018.0
# 544         2182736.0    59.80       1305197.0
#
# [423 rows x 10 columns]

# %%
plt.figure(figsize=(20,6))
plt.stem(party_vote_list.index,party_vote_list["Count of Votes"])
plt.ylabel("Number of Voters")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.stem(party_vote_list.index,party_vote_list["Count of Elector"])
plt.ylabel("Number of Eligible Voters")
plt.xticks(rotation=90)
plt.show()

# %%
party_vote_list["Votes-Total_Votes_Ratio"] = (party_vote_list["Total Votes"]/party_vote_list["Count of Votes"])*100
party_vote_list.head()
# Out:
#   Parliament Constituency  Winning Candidate  Total Votes  Margin  \
# 0              MALKAJGIRI    EATALA RAJENDER       991042  391475
# 1         BANGALORE NORTH  SHOBHA KARANDLAJE       986049  259476
# 2                  BHOPAL        ALOK SHARMA       981109  501499
# 3                    DURG       VIJAY BAGHEL       956497  438226
# 4                MANDSOUR      SUDHEER GUPTA       945761  500655
#
#    margin-votes ratio Consistuency_no           State  Count of Elector  \
# 0           39.501353             (7)       Telangana         3779596.0
# 1           26.314717            (24)       Karnataka         3214496.0
# 2           51.115523            (19)  Madhya Pradesh         2339411.0
# 3           45.815721             (7)    Chhattisgarh         2090414.0
# 4           52.936736            (23)  Madhya Pradesh         1898060.0
#
#    Poll(%)  Count of Votes  Votes-Total_Votes_Ratio
# 0    50.78       1919131.0                51.640143
# 1    54.45       1750372.0                56.333682
# 2    64.06       1498626.0                65.467235
# 3    73.68       1540193.0                62.102412
# 4    75.27       1428623.0                66.200880

# %%
party_vote_list["Margin-Total_Votes_Ratio"] = (party_vote_list["Margin"]/party_vote_list["Count of Votes"])*100
party_vote_list.head()
# Out:
#   Parliament Constituency  Winning Candidate  Total Votes  Margin  \
# 0              MALKAJGIRI    EATALA RAJENDER       991042  391475
# 1         BANGALORE NORTH  SHOBHA KARANDLAJE       986049  259476
# 2                  BHOPAL        ALOK SHARMA       981109  501499
# 3                    DURG       VIJAY BAGHEL       956497  438226
# 4                MANDSOUR      SUDHEER GUPTA       945761  500655
#
#    margin-votes ratio Consistuency_no           State  Count of Elector  \
# 0           39.501353             (7)       Telangana         3779596.0
# 1           26.314717            (24)       Karnataka         3214496.0
# 2           51.115523            (19)  Madhya Pradesh         2339411.0
# 3           45.815721             (7)    Chhattisgarh         2090414.0
# 4           52.936736            (23)  Madhya Pradesh         1898060.0
#
#    Poll(%)  Count of Votes  Votes-Total_Votes_Ratio  Margin-Total_Votes_Ratio
# 0    50.78       1919131.0                51.640143                 20.398555
# 1    54.45       1750372.0                56.333682                 14.824049
# 2    64.06       1498626.0                65.467235                 33.463920
# 3    73.68       1540193.0                62.102412                 28.452668
# 4    75.27       1428623.0                66.200880                 35.044585

# %% [markdown]
# Top 5 largest consistuency based on number of electors

# %%
sorted_electors_list = party_vote_list.sort_values(by="Count of Elector",ascending = 0)
sorted_electors_list.head()
# Out:
#     Parliament Constituency        Winning Candidate  Total Votes  Margin  \
# 0                MALKAJGIRI          EATALA RAJENDER       991042  391475
# 1           BANGALORE NORTH        SHOBHA KARANDLAJE       986049  259476
# 24                GHAZIABAD                ATUL GARG       854170  336965
# 35                 CHEVELLA  KONDA VISHWESHWAR REDDY       809882  172897
# 539         BANGALORE RURAL         DR C N MANJUNATH      1079002  269647
#
#      margin-votes ratio Consistuency_no          State  Count of Elector  \
# 0             39.501353             (7)      Telangana         3779596.0
# 1             26.314717            (24)      Karnataka         3214496.0
# 24            39.449407            (12)  Uttar Pradesh         2945487.0
# 35            21.348419            (10)      Telangana         2938370.0
# 539           24.990408            (23)      Karnataka         2802580.0
#
#      Poll(%)  Count of Votes  Votes-Total_Votes_Ratio
# 0      50.78       1919131.0                51.640143
# 1      54.45       1750372.0                56.333682
# 24     49.88       1469260.0                58.136068
# 35     56.40       1657107.0                48.873247
# 539    68.30       1914030.0                56.373307

# %% [markdown]
# Ghaziabad has the most winning votes ratio ,by the winning party, among the top 5 biggest consistuency.

# %% [markdown]
# Top 5 consistuency with high margin-total votes posted ratio

# %%
sorted_margin_list = party_vote_list.sort_values(by="Margin-Total_Votes_Ratio",ascending = 0)
sorted_margin_list.head()
# Out:
#     Parliament Constituency      Winning Candidate  Total Votes   Margin  \
# 536                  INDORE        SHANKAR LALWANI      1226751  1175092
# 542                 NAVSARI              C R PATIL      1031065   773551
# 544             GANDHINAGAR              AMIT SHAH      1010972   744716
# 538                 VIDISHA  SHIVRAJ SINGH CHOUHAN      1116460   821408
# 13             TRIPURA WEST       BIPLAB KUMAR DEB       881341   611578
#
#      margin-votes ratio Consistuency_no           State  Count of Elector  \
# 536           95.788958            (26)  Madhya Pradesh         2526803.0
# 542           75.024465            (25)         Gujarat         2223550.0
# 544           73.663366             (6)         Gujarat         2182736.0
# 538           73.572542            (18)  Madhya Pradesh         1945404.0
# 13            69.391756             (1)         Tripura         1463526.0
#
#      Poll(%)  Count of Votes  Votes-Total_Votes_Ratio  \
# 536    61.67       1558341.0                78.721602
# 542    59.66       1326542.0                77.725771
# 544    59.80       1305197.0                77.457426
# 538    74.48       1449010.0                77.049848
# 13     81.48       1192435.0                73.911031
#
#      Margin-Total_Votes_Ratio
# 536                 75.406602
# 542                 58.313344
# 544                 57.057747
# 538                 56.687531
# 13                  51.288162

# %% [markdown]
# Shankar Lalwani won the election with 75percent votes more than trailing candidate in Indore.

# %%
state_wise_voters = party_vote_list.groupby('State')['Count of Elector'].sum().sort_values(ascending=False)
state_wise_voters
# Out:
# State
# Uttar Pradesh                           103816680.0
# Maharashtra                              91127327.0
# Tamil Nadu                               62333925.0
# Madhya Pradesh                           56595333.0
# Karnataka                                54725675.0
# Rajasthan                                51298563.0
# Gujarat                                  47982446.0
# Bihar                                    47824736.0
# West Bengal                              45135433.0
# Andhra Pradesh                           41333702.0
# Telangana                                28278967.0
# Kerala                                   25079782.0
# Assam                                    24506236.0
# Chhattisgarh                             20658430.0
# Odisha                                   14257109.0
# Jharkhand                                12292654.0
# Uttarakhand                               8337914.0
# Jammu and Kashmir                         6889705.0
# Tripura                                   2860287.0
# Meghalaya                                 2226567.0
# Manipur                                   2029601.0
# Nagaland                                  1317536.0
# Goa                                       1179344.0
# Puducherry                                1023699.0
# Arunachal Pradesh                          892694.0
# Mizoram                                    856364.0
# Sikkim                                     464140.0
# Dadra & Nagar Haveli and Daman & Diu       417213.0
# Andaman & Nicobar Islands                  315148.0
# Ladakh                                     184808.0
# Lakshadweep                                 57784.0
# Name: Count of Elector, dtype: float64

# %%
state_wise_votes = party_vote_list.groupby('State')['Count of Votes'].sum().sort_values(ascending=False)
plt.stem(state_wise_votes.index,state_wise_votes)
plt.xlabel("States")
plt.ylabel("Votes Received")
plt.xticks(rotation=90)
plt.show()
state_wise_votes
# Out:
# State
# Uttar Pradesh                           60214434.0
# Maharashtra                             55829887.0
# Tamil Nadu                              43458875.0
# Karnataka                               38657725.0
# Madhya Pradesh                          37847251.0
# West Bengal                             35697704.0
# Andhra Pradesh                          33340560.0
# Rajasthan                               31740548.0
# Gujarat                                 28854134.0
# Bihar                                   27082371.0
# Assam                                   19988275.0
# Telangana                               18240848.0
# Kerala                                  17917173.0
# Chhattisgarh                            15040444.0
# Odisha                                  10616636.0
# Jharkhand                                7951112.0
# Uttarakhand                              4771288.0
# Jammu and Kashmir                        4094087.0
# Tripura                                  2314859.0
# Meghalaya                                1705535.0
# Manipur                                  1588215.0
# Goa                                       896958.0
# Puducherry                                807724.0
# Nagaland                                  760507.0
# Arunachal Pradesh                         693441.0
# Mizoram                                   487013.0
# Sikkim                                    370765.0
# Dadra & Nagar Haveli and Daman & Diu      297527.0
# Andaman & Nicobar Islands                 202018.0
# Ladakh                                    132727.0
# Lakshadweep                                48630.0
# Name: Count of Votes, dtype: float64

# %%
state_wise_poll_percent = party_vote_list.groupby('State')['Poll(%)'].max().sort_values(ascending=False)
plt.stem(state_wise_poll_percent.index,state_wise_poll_percent)
plt.xlabel("Poll(%)")
plt.ylabel("States")
plt.xticks(rotation=90)
plt.show()
state_wise_poll_percent
# Out:
# State
# Assam                                   92.08
# Andhra Pradesh                          87.06
# Manipur                                 85.11
# Lakshadweep                             84.16
# West Bengal                             83.66
# Arunachal Pradesh                       83.31
# Odisha                                  82.16
# Karnataka                               81.67
# Tripura                                 81.48
# Meghalaya                               81.37
# Tamil Nadu                              81.20
# Chhattisgarh                            79.89
# Sikkim                                  79.88
# Madhya Pradesh                          79.83
# Puducherry                              78.90
# Kerala                                  78.41
# Goa                                     77.69
# Telangana                               76.09
# Rajasthan                               75.93
# Gujarat                                 72.71
# Dadra & Nagar Haveli and Daman & Diu    72.52
# Jammu and Kashmir                       72.22
# Maharashtra                             71.88
# Ladakh                                  71.82
# Jharkhand                               69.93
# Uttar Pradesh                           67.20
# Andaman & Nicobar Islands               64.10
# Bihar                                   63.76
# Uttarakhand                             63.53
# Nagaland                                57.72
# Mizoram                                 56.87
# Name: Poll(%), dtype: float64

# %%
state_wise_min_percent = party_vote_list.groupby('State')['Poll(%)'].min().sort_values(ascending=False)
plt.stem(state_wise_min_percent.index,state_wise_min_percent)
plt.xlabel("Poll(%)")
plt.ylabel("State")
plt.xticks(rotation=90)
plt.show()
state_wise_min_percent
# Out:
# State
# Lakshadweep                             84.16
# Tripura                                 80.36
# Sikkim                                  79.88
# Puducherry                              78.90
# Assam                                   75.74
# Goa                                     74.47
# Meghalaya                               73.78
# Arunachal Pradesh                       73.60
# Ladakh                                  71.82
# West Bengal                             71.73
# Andhra Pradesh                          71.11
# Manipur                                 68.83
# Dadra & Nagar Haveli and Daman & Diu    68.77
# Chhattisgarh                            64.77
# Andaman & Nicobar Islands               64.10
# Kerala                                  63.37
# Odisha                                  62.67
# Jharkhand                               61.27
# Nagaland                                57.72
# Mizoram                                 56.87
# Tamil Nadu                              53.96
# Karnataka                               53.17
# Gujarat                                 50.29
# Maharashtra                             50.06
# Rajasthan                               49.59
# Madhya Pradesh                          49.43
# Uttar Pradesh                           49.41
# Uttarakhand                             48.74
# Telangana                               48.48
# Bihar                                   43.17
# Jammu and Kashmir                       38.49
# Name: Poll(%), dtype: float64

# %% [markdown]
# #Tripura and Lakshwadeep as the highesest minimum voter turn out in india as they have only 1 or 2 consistuencies
